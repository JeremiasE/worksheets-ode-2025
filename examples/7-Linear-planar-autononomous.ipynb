# %%
# vector_fields.py contains a bunch of tools to visualize vector fields and related objects
# this line is mainly needed to run the notebook in google colab or kaggle
_ = !wget https://raw.githubusercontent.com/JeremiasE/worksheets-ode-2025/main/tools/vector_fields.py

# %%
import IPython.display as disp
import sympy
import vector_fields
from sympy import init_printing
init_printing()

# %%
(t,x,y)=sympy.var("t,x,y")

# %%
vector = sympy.Matrix
matrix = sympy.Matrix

# %%
def normalize(f):
    norm = sympy.sqrt(f[0]**2+f[1]**2)
    return f/norm

# %%
def plot_linear_system(A,color="#267ab2",show_vars=True):
    f = A*vector([x,y])
    ax = vector_fields.plot_vector_field(normalize(f),(x,-8,8),(y,-8,8),color="lightgrey")
    vector_fields.plot_streamlines(f, (x,-8,8), (y,-8,8),color=color,ax = ax)
    ax.set_aspect('equal')
    if show_vars:
        disp.display(disp.Math(f'$$A= {sympy.latex(A)}$$'))
        disp.display(disp.Math(f'$$e^{{tA}}= {sympy.latex(sympy.simplify(sympy.exp(t*A)))}$$'))
        disp.display(disp.Math(f'$$\\sigma(A)= \\{{{sympy.latex(str(A.eigenvals(simplify=True, multiple=True))[1:-1])}\\}}$$'))
    ax.set_xlabel('$x$')
    return ax

def visualize_linear_system(A):
    f = A*vector([x,y])
    return vector_fields.field_player(f)

# %% [markdown]
# # Phasenportäts linearer autonomer planarer Differentialgleichungen

# %% [markdown]
# Im folgenden stellen wir stets Phasenkurven bzw. Trajektorien (also Teilmengen der Ebene, die durch Lösungen der DGL parametrisiert sind) der DGL
# $$\begin{pmatrix} \dot x(t) \\ \dot y(t) \end{pmatrix} = A \begin{pmatrix} x(t) \\ y(t) \end{pmatrix}$$ dar.

# %% [markdown]
# ## Instabiler Knoten

# %%
A = matrix([[1,0],[0,1]])
plot_linear_system(A);
# Out:
# $\displaystyle A= \left[\begin{matrix}1 & 0\\0 & 1\end{matrix}\right]$
# $\displaystyle e^{tA}= \left[\begin{matrix}e^{t} & 0\\0 & e^{t}\end{matrix}\right]$
# $\displaystyle \sigma(A)= \{\mathtt{\text{1, 1}}\}$

# %%
A = matrix([[2,0],[0,1]])
plot_linear_system(A);
# Out:
# $\displaystyle A= \left[\begin{matrix}2 & 0\\0 & 1\end{matrix}\right]$
# $\displaystyle e^{tA}= \left[\begin{matrix}e^{2 t} & 0\\0 & e^{t}\end{matrix}\right]$
# $\displaystyle \sigma(A)= \{\mathtt{\text{2, 1}}\}$

# %%
A = matrix([[1,1],[0,1]])
plot_linear_system(A);
# Out:
# $\displaystyle A= \left[\begin{matrix}1 & 1\\0 & 1\end{matrix}\right]$
# $\displaystyle e^{tA}= \left[\begin{matrix}e^{t} & t e^{t}\\0 & e^{t}\end{matrix}\right]$
# $\displaystyle \sigma(A)= \{\mathtt{\text{1, 1}}\}$

# %% [markdown]
# ## Stabiler Knoten

# %%
A = matrix([[-2,0],[0,-1]])
plot_linear_system(A);
# Out:
# $\displaystyle A= \left[\begin{matrix}-2 & 0\\0 & -1\end{matrix}\right]$
# $\displaystyle e^{tA}= \left[\begin{matrix}e^{- 2 t} & 0\\0 & e^{- t}\end{matrix}\right]$
# $\displaystyle \sigma(A)= \{\mathtt{\text{-2, -1}}\}$

# %%
A = matrix([[-1,1],[0,-1]])
plot_linear_system(A);
# Out:
# $\displaystyle A= \left[\begin{matrix}-1 & 1\\0 & -1\end{matrix}\right]$
# $\displaystyle e^{tA}= \left[\begin{matrix}e^{- t} & t e^{- t}\\0 & e^{- t}\end{matrix}\right]$
# $\displaystyle \sigma(A)= \{\mathtt{\text{-1, -1}}\}$

# %% [markdown]
# ## Sattel

# %%
A = matrix([[1,0],[0,-1]])
plot_linear_system(A);
# Out:
# $\displaystyle A= \left[\begin{matrix}1 & 0\\0 & -1\end{matrix}\right]$
# $\displaystyle e^{tA}= \left[\begin{matrix}e^{t} & 0\\0 & e^{- t}\end{matrix}\right]$
# $\displaystyle \sigma(A)= \{\mathtt{\text{1, -1}}\}$

# %%
C = matrix([[1,0],[0,-1]])
P = matrix([[1,0],[1,1]])
plot_linear_system(P*C*P**(-1));
# Out:
# $\displaystyle A= \left[\begin{matrix}1 & 0\\2 & -1\end{matrix}\right]$
# $\displaystyle e^{tA}= \left[\begin{matrix}e^{t} & 0\\2 \sinh{\left(t \right)} & e^{- t}\end{matrix}\right]$
# $\displaystyle \sigma(A)= \{\mathtt{\text{1, -1}}\}$

# %% [markdown]
# ## Stabiler Strudel

# %%
A = matrix([[-2,-1],[1,-2]])
plot_linear_system(A,color=(0.7,0.1,0.1));
# Out:
# $\displaystyle A= \left[\begin{matrix}-2 & -1\\1 & -2\end{matrix}\right]$
# $\displaystyle e^{tA}= \left[\begin{matrix}e^{- 2 t} \cos{\left(t \right)} & - e^{- 2 t} \sin{\left(t \right)}\\e^{- 2 t} \sin{\left(t \right)} & e^{- 2 t} \cos{\left(t \right)}\end{matrix}\right]$
# $\displaystyle \sigma(A)= \{\mathtt{\text{-2 + I, -2 - I}}\}$

# %% [markdown]
# # Instabiler Strudel

# %%
A = matrix([[2,-1],[1,2]])
plot_linear_system(A,color=(0.7,0.1,0.1));
# Out:
# $\displaystyle A= \left[\begin{matrix}2 & -1\\1 & 2\end{matrix}\right]$
# $\displaystyle e^{tA}= \left[\begin{matrix}\frac{e^{t \left(2 - i\right)}}{2} + \frac{e^{t \left(2 + i\right)}}{2} & \frac{i \left(- e^{t \left(2 - i\right)} + e^{t \left(2 + i\right)}\right)}{2}\\\frac{i \left(e^{t \left(2 - i\right)} - e^{t \left(2 + i\right)}\right)}{2} & \frac{e^{t \left(2 - i\right)}}{2} + \frac{e^{t \left(2 + i\right)}}{2}\end{matrix}\right]$
# $\displaystyle \sigma(A)= \{\mathtt{\text{2 + I, 2 - I}}\}$

# %% [markdown]
# # Zentrum

# %%
A = matrix([[0,-1],[1,0]])
plot_linear_system(A)
# Out:
# $\displaystyle A= \left[\begin{matrix}0 & -1\\1 & 0\end{matrix}\right]$
# $\displaystyle e^{tA}= \left[\begin{matrix}\cos{\left(t \right)} & - \sin{\left(t \right)}\\\sin{\left(t \right)} & \cos{\left(t \right)}\end{matrix}\right]$
# $\displaystyle \sigma(A)= \{\mathtt{\text{I, -I}}\}$
# <Axes: xlabel='$x$'>

# %%
A = matrix([[0,-4],[1,0]])
plot_linear_system(A)
# Out:
# $\displaystyle A= \left[\begin{matrix}0 & -4\\1 & 0\end{matrix}\right]$
# $\displaystyle e^{tA}= \left[\begin{matrix}\cos{\left(2 t \right)} & - 2 \sin{\left(2 t \right)}\\\frac{\sin{\left(2 t \right)}}{2} & \cos{\left(2 t \right)}\end{matrix}\right]$
# $\displaystyle \sigma(A)= \{\mathtt{\text{-2*I, 2*I}}\}$
# <Axes: xlabel='$x$'>

# %% [markdown]
# ## Degenerierte Fälle

# %%
A = matrix([[0,1],[0,0]])
plot_linear_system(A,color="green")
# Out:
# $\displaystyle A= \left[\begin{matrix}0 & 1\\0 & 0\end{matrix}\right]$
# $\displaystyle e^{tA}= \left[\begin{matrix}1 & t\\0 & 1\end{matrix}\right]$
# $\displaystyle \sigma(A)= \{\mathtt{\text{0, 0}}\}$
# <Axes: xlabel='$x$'>

# %%
A = matrix([[0,0],[0,2]])
plot_linear_system(A,color=(0.1,0.5,0.2))
# Out:
# $\displaystyle A= \left[\begin{matrix}0 & 0\\0 & 2\end{matrix}\right]$
# $\displaystyle e^{tA}= \left[\begin{matrix}1 & 0\\0 & e^{2 t}\end{matrix}\right]$
# $\displaystyle \sigma(A)= \{\mathtt{\text{0, 2}}\}$
# <Axes: xlabel='$x$'>

# %%
A = matrix([[0,0],[0,-2]])
plot_linear_system(A,color=(0.1,0.5,0.2))
# Out:
# $\displaystyle A= \left[\begin{matrix}0 & 0\\0 & -2\end{matrix}\right]$
# $\displaystyle e^{tA}= \left[\begin{matrix}1 & 0\\0 & e^{- 2 t}\end{matrix}\right]$
# $\displaystyle \sigma(A)= \{\mathtt{\text{0, -2}}\}$
# <Axes: xlabel='$x$'>
