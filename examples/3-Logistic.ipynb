# %%
# vector_fields.py contains a bunch of tools to visualize vector fields and related objects
# this line is mainly needed to run the notebook in google colab or kaggle
_ = !wget https://raw.githubusercontent.com/JeremiasE/worksheets-ode-2025/main/tools/vector_fields.py

# %%
import sympy
from sympy import sin,exp
from sympy.utilities import lambdify

import numpy as np
import matplotlib.pyplot as plt

import vector_fields

# %%
sympy.var("x y t")
# Out:
# (x, y, t)

# %% [markdown]
# # Logistisches Wachstum

# %% [markdown]
# Wir betrachten das Anfangswertproblem
# $\dot x = x(1-x), x(0)=x_0$.

# %% [markdown]
# Als Lösungen erhalten wir (siehe Harro Heuser: Gewöhnliche Differentialgleichungen, 6. Auflage, Seite 22)
# \begin{align*}
#     t \mapsto \frac{1}{\left(\frac{1}{x_{0}}-1\right) e^{- t} + 1}
# \end{align*}

# %% [markdown]
# ## Lösungsporträt

# %%
ax = vector_fields.plot_slope_field(x*(1-x),(t,-3,3),(x,-2,2),color="tab:grey")
ax.set_xlabel("$t$")
ax.set_ylabel("$x$")
vector_fields.add_central_axis(ax)
for x0, color in zip((0.1,0.5,0.9), ("tab:purple","tab:blue","tab:green")):
    vector_fields.plot(1/((1/x0-1)*exp(-t)+1),(t,-3,3),numpoints=5000,ax=ax, color=color)
x0 = 2.9
vector_fields.plot(1/((1/x0-1)*exp(-t)+1),(t,0,3),ax=ax, color="tab:orange")
x0= -1
vector_fields.plot(1/((1/x0-1)*exp(-t)+1),(t,-3,0.5),ax=ax, color="tab:cyan")
    
vector_fields.plot(1,(t,-3,3),ylimits=(-2,2),ax=ax, color="tab:pink")
    
vector_fields.plot(-2,(t,-3,3),ylimits=(-2,2),ax=ax, color="tab:olive")
ax.set_xlim(-3,3)
ax.set_ylim(-2,2)
plt.show()

# %% [markdown]
# ## Lösungsfluss

# %%
f = sympy.Matrix([1,(1-y)*y])
vector_fields.field_player(f)
# Out:
#         <iframe
#             width="1300"
#             height="700"
#             src="https://anvaka.github.io/fieldplay/?cx=0.0017000000000000348&cy=0&w=8.543199999999999&h=8.543199999999999&dt=0.01&fo=0.998&dp=0.009&cm=1&vf=vec2%20get_velocity%28vec2%20p%29%20%7B%0A%20%20%20%20vec2%20v%20%3D%20vec2%280.%2C%200.%29%3B%0A%20%20%20%20float%20x%20%3D%20p.x%3B%0A%20%20%20%20float%20y%20%3D%20p.y%3B%0A%20%20%20%20v.x%20%3D%201.00000000000000%3B%0A%20%20%20%20v.y%20%3D%20y%2A%281.0%20-%20y%29%3B%0A%20%20%20%20return%20v%3B%0A%20%20%20%20%7D"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
